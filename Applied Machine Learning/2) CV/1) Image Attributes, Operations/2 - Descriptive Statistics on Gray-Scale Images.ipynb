# %% [markdown]
# [[1 - Images as Arrays]] $\leftarrow$ Back
#
# ---
# # Descriptive Statistics

# %%
import matplotlib.pyplot as pyplot
import cv2
import numpy

imgFilePath = r"C:\Users\benja\OneDrive\Pictures\grayscaleImage.jpg"

img = cv2.imread(imgFilePath)
plt.imshow(img)
